# %%
from coriskyscene.scene_visualization import scene_vis as scvis
from coriskyscene.scene_generation import traffic_scene as trasc

# %%
# replace as your local path
path = "/home/lrs/scripts/CoRiskyScene/coriskyscene/scene_generation/data/overtake.json"
loaded_scene_list = trasc.load_traffic_scenes(path)
print("total scenes: {0}".format(len(loaded_scene_list)))
_ = scvis.draw_scene(loaded_scene_list[1], figsize=(15,6))
_ = scvis.draw_scene(loaded_scene_list[20], figsize=(15,6))
_ = scvis.draw_scene(loaded_scene_list[30], figsize=(15,6))
_ = scvis.draw_scene(loaded_scene_list[400], figsize=(15,6))
_ = scvis.draw_scene(loaded_scene_list[500], figsize=(15,6))
# Out:
# total scenes: 656
